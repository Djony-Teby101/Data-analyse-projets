# %%
import pandas as pd
import numpy as np
import matplotlib as plt

#Chargement de la Data.
df_ventes=pd.read_csv('ventes.csv')

# Conversion de la colonne date en datetime.
df_ventes['date']=pd.to_datetime(df_ventes['date'])
df_ventes
# Out:
#     id_magasin       date  chiffre_affaires region_ville
# 0            1 2020-12-01          17498.18   Libreville
# 1            1 2021-12-01          15849.54   Libreville
# 2            1 2022-12-01          18835.44   Libreville
# 3            1 2023-12-01          18077.40   Libreville
# 4            2 2020-12-01          12617.48   Libreville
# 5            2 2021-12-01          13647.43   Libreville
# 6            2 2022-12-01          15278.30   Libreville
# 7            2 2023-12-01          15254.77   Libreville
# 8            3 2020-12-01          14164.47   Libreville
# 9            3 2021-12-01          17244.96   Libreville
# 10           3 2022-12-01          15628.08   Libreville
# 11           3 2023-12-01          18888.03   Libreville
# 12           4 2020-12-01           9969.96   Libreville
# 13           4 2021-12-01          10707.97   Libreville
# 14           4 2022-12-01          11619.18   Libreville
# 15           4 2023-12-01          10948.45   Libreville
# 16           5 2020-12-01          12461.25   Libreville
# 17           5 2021-12-01          13705.16   Libreville
# 18           5 2022-12-01          13638.08   Libreville
# 19           5 2023-12-01          13155.84   Libreville
