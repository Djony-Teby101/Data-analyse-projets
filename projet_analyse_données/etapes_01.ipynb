# %%
import pandas as pd
import numpy as np
import matplotlib as plt

#Chargement de la Data.
df_ventes=pd.read_csv('ventes.csv')

# Conversion de la colonne date en datetime.
df_ventes['date']=pd.to_datetime(df_ventes['date'])

#Apercu des données.
df_ventes.head()
# Information generales.
df_ventes.info()

# Statistique description.
print(df_ventes['chiffre_affaires'].describe())

# Verification des valeurs manquantes.
print("\n--- valeurs manquantes par colonne---")
print(df_ventes.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_magasin        20 non-null     int64
#  1   date              20 non-null     datetime64[ns]
#  2   chiffre_affaires  20 non-null     float64
#  3   region_ville      20 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 772.0+ bytes
# count       20.00000
# mean     14459.49850
# std       2706.16876
# min       9969.96000
# 25%      12578.42250
# 50%      13934.81500
# 75%      16198.39500
# max      18888.03000
# Name: chiffre_affaires, dtype: float64
#
# --- valeurs manquantes par colonne---
# id_magasin          0
# date                0
# chiffre_affaires    0
# region_ville        0
# dtype: int64
